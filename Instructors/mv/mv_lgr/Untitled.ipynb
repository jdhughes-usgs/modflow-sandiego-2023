# %%
import flopy
import matplotlib.pyplot as plt
import numpy as np

# %%
fname = '/Users/langevin/langevin/dev/flopy3fork.git/autotest/temp/t007/shapefile/myarraycontours.shp'
xmin, xmax, ymin, ymax = flopy.plot.shapefile_extents(fname)
flopy.plot.plot_shapefile(fname)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
# Out:
# (0.5499999999999998, 7.1499999999999995)

# %%
nrow = 7
ncol = 11
a = np.arange((nrow * ncol)).reshape((nrow, ncol))
plt.contourf(np.flipud(a))
